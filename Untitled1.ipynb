# %% [markdown]
# -- Assignment Sollution --
#
# create database company_db;
#
# drop table  employees;
#
# use company_db;
#
#
# create table employees(
# employee_id int primary key,
#
# first_name varchar(50),
#
# last_name varchar(50),
#
# department varchar(50),
#
# salary int,
#
# hire_date date
# );
#
# select * from employees;
#
# -- 02 Insert data  employees table \\.
#
#
# insert into employees(employee_id ,first_name,last_name,department,salary,hire_date)
# values(101,'Amit','Sharma','HR',50000,'2020-01-15'),
#     (102,'Riya','Kapur','Sales',75000,'2019-03-22'),
#     (103,'Raj','Mehta', 'IT',900000,'2018-07-11'),
#     (104,'Neha','Verma','IT',85000,'2021-09-01'),
#     (105,'Arjun','Singh','Finance',60000,'2022-02-10');
#
#
# select * from employees;
#
#
# -- 03 Display All Employee Records Sorted by Salary (Lowest to Highest)//.
#
# select * from employees order by salary Asc;
#
# -- 04 Show Employees Sorted by department (A–Z) and Salary (High → Low)\\.
#
#
# select * from employees order by department Asc,salary desc;
#
# -- 05  List All Employees in the IT Department, Ordered by Hire Date (Newest First)
#
#
#  select * from employees
#
#  where department = 'IT'
#  order by hire_date DESC;
#
#
# -- 06 Create and Populate a Sales Table
#
#
#  create table sales(sale_id int primary key,
#  customer_name varchar(50) not null,
#  amount int,
#
#  sale_date date
#  );
#
#
# select * from sales;
#
#
#
# insert into sales(sale_id,customer_name,amount,sale_date)
#
# values('1','Aditi',1500,'2024-08-01'),
# ('2','Rohan',2200,'2024-08-03'),
# ('3','Aditi',3500,'2024-09-05'),
# ('4','Meena',2700,'2024-09-15'),
# ('5','Rohan',4500,'2024-09-25');
#
#
#
# -- 07 Display All Sales Records Sorted by Amount (Highest → Lowest)
#
#
#
# select * from sales
# order by amount Desc;
#
#
#
#  -- 08  Show All Sales Made by Customer “Aditi”
#
#
#
# select * from sales
#
# where customer_name = 'Aditi';
#
#
#
# use company_db
#
#
# -- 09 What is the Difference Between a Primary Key and a Foreign Key?
#
#
# --  Primary Key
# -- A column that uniquely identifies each record in a table,
#
# --   unique identifier inside itsoen table
#
#
#  -- Foreign key
#  -- A column in one table that references the primary key if another table
#
#  -- linke to another table's primary key ,creating a relation.
#
#
#
#  -- 10  What Are Constraints in SQL and Why Are They Used?
#
#
#  -- Constraints in MY SQL are rules applied to the table column to control, what data cane be stored.
